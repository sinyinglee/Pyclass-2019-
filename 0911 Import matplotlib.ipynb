# %%
2+2
# Out:
# 4

# %%
2+2
# Out:
# 4

# %%
# %matplotlib inline

import numpy as np 
import matplotlib.pyplot as plt

# %%
np.sin(1/2 *np.pi)
# Out:
# 1.0

# %%
y = [2, 3, -5, -4, -8]

# %%
plt.plot(y)
#plot 畫圖function

# %%
x = [0, 0.5, 0.7, 0.9, 1.3]

# %%
plt.scatter(x, y)

# %%
x = np.linspace(-10, 10, 100)
#前面兩個數字是範圍，最後一個是切割的數量

# %%
y = np.sin(x)

# %%
plt.plot(x, y)

# %%
plt.xkcd()

# %%
plt.plot(x,y)
