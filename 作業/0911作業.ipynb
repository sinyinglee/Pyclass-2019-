# %%
# %matplotlib inline

import numpy as np 
import matplotlib.pyplot as plt

# %%
y = [1000, 400, -200, 600, 11, 15]

# %%
x = np.cos(y)

# %%
plt.plot(x,y)

# %%
# %matplotlib inline

import numpy as np 
import matplotlib.pyplot as plt

# %%
x = [0.5, 0.7, 0.8, 1.3, 2.5]

# %%
y = np.sin(x)

# %%
plt.xkcd()

# %%
plt.plot(x,y)
