# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding
from tensorflow.keras.layers import LSTM
from tensorflow.keras.datasets import imdb

# %%
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=10000)

# %%
# 切成長度一樣的數字
x_train = sequence.pad_sequences(x_train, maxlen=100)
x_test = sequence.pad_sequences(x_test, maxlen=100)

# %%
model = Sequential()

# %%
model.add(Embedding(10000, 128))

# %%
# dropout, 可以避免overfitting
model.add(LSTM(256, dropout=0.2, recurrent_dropout=0.2))

# %%
# sigmoid, 輸出都是0-1的數字
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, None, 128)         1280000
# _________________________________________________________________
# lstm (LSTM)                  (None, 256)               394240
# _________________________________________________________________
# dense (Dense)                (None, 1)                 257
# =================================================================
# Total params: 1,674,497
# Trainable params: 1,674,497
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 訓練：測試資料跑10次訓練

# %%
model.fit(x_train, y_train, batch_size=32, epochs=10,
         validation_data=(x_test, y_test))
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/10
# 25000/25000 [==============================] - 317s 13ms/sample - loss: 0.4764 - accuracy: 0.7762 - val_loss: 0.3771 - val_accuracy: 0.8338
# Epoch 2/10
# 25000/25000 [==============================] - 239s 10ms/sample - loss: 0.3390 - accuracy: 0.8586 - val_loss: 0.3945 - val_accuracy: 0.8337
# Epoch 3/10
# 25000/25000 [==============================] - 258s 10ms/sample - loss: 0.2706 - accuracy: 0.8905 - val_loss: 0.3821 - val_accuracy: 0.8386
# Epoch 4/10
# 25000/25000 [==============================] - 232s 9ms/sample - loss: 0.2211 - accuracy: 0.9143 - val_loss: 0.4433 - val_accuracy: 0.8190
# Epoch 5/10
# 25000/25000 [==============================] - 261s 10ms/sample - loss: 0.1723 - accuracy: 0.9359 - val_loss: 0.4275 - val_accuracy: 0.8386
# Epoch 6/10
# 25000/25000 [==============================] - 261s 10ms/sample - loss: 0.1326 - accuracy: 0.9512 - val_loss: 0.4864 - val_accuracy: 0.8396
# Epoch 7/10
# 25000/25000 [==============================] - 262s 10ms/sample - loss: 0.1031 - accuracy: 0.9638 - val_loss: 0.5427 - val_accuracy: 0.8223
# Epoch 8/10
# 25000/25000 [==============================] - 260s 10ms/sample - loss: 0.0802 - accuracy: 0.9718 - val_loss: 0.6203 - val_accuracy: 0.8250
# Epoch 9/10
# 25000/25000 [==============================] - 302s 12ms/sample - loss: 0.0635 - accuracy: 0.9781 - val_loss: 0.6596 - val_accuracy: 0.8060
# Epoch 10/10
# 25000/25000 [==============================] - 257s 10ms/sample - loss: 0.0530 - accuracy: 0.9818 - val_loss: 0.6772 - val_accuracy: 0.8286

# %%
score = model.evaluate(x_test, y_test)
# Out:
# 25000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %% [markdown]
# ### 印出訓練正確率

# %%
print(f'訓練正確率 = {score[1]}')
# Out:
# 訓練正確率 = 0.8285599946975708

# %% [markdown]
# ### 把model存起來

# %%
model_json = model.to_json()
open('imdb_model_arch.json',
     'w').write(model_json)
model.save_weights('imdb_model_weights.h5')
