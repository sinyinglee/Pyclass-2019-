# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# %ls
# Out:
# 0911 Import matplotlib.ipynb
# 0918上課markdown, while迴圈,plot簡易畫圖,interact功能.ipynb
# 0925上課List,For迴圈.ipynb
# 1.jpeg
# 1002上課random使用.ipynb
# 1009上課Map,Lambda,Print格式化,Display.ipynb
# 1011數據分析moocs.ipynb
# 1016上課Class,csv檔案存取.ipynb
# 1023上課(Array, Sympy).ipynb
# 1027練習.ipynb
# 1030 Pandas.ipynb
# 1113 機器學習(線性迴歸）.ipynb
# 1120 圖形辨識.ipynb
# 1127上課.ipynb
# 2.jpg
# 3.jpeg
# 4.jpeg
# 5.jpeg
# 6.jpeg
# Copy of ITF總表.xlsx
# IntoTheWild.jpg
# Iris Flower預測作業.ipynb
# KKday Aug.csv
# KKday Aug.xlsx
# KKday, pandas-test.ipynb
# Pandas - .ipynb
# READ.md
# difference.xlsx
# july_id.csv
# kkday July.csv
# kkday.ipynb
# mydic.csv
# newdic.pickle
# poem.py
# test.txt
# 作業/
# 使用IPywidgets(總整理）.ipynb
# 機器學習.ipynb

# %%
df = pd.read_csv("http://bit.ly/gradescsv")

# %%
df.head()
# Out:
#     姓名  國文  英文  數學  自然  社會
# 0  劉俊安   9  10  15  10  13
# 1  胡玉華  10  10  10   8   9
# 2  黃淑婷  13  15   8  11  14
# 3  陳上紫  10  10   8   9  14
# 4  崔靜成  13  12  14  12  13

# %%
cg = df.國文.values

# %%
cg.std()
# Out:
# 2.1858407993264284

# %%
df.國文.plot()

# %%
df.國文.hist(bins = 15)

# %%
df.describe()
# Out:
#                國文          英文          數學         自然         社會
# count  100.000000  100.000000  100.000000  100.00000  100.00000
# mean    11.390000   11.380000   11.570000   11.03000   11.83000
# std      2.196853    2.273164    2.310516    2.21772    2.48655
# min      8.000000    8.000000    8.000000    8.00000    8.00000
# 25%      9.000000    9.000000   10.000000    9.00000    9.00000
# 50%     11.000000   11.000000   11.000000   11.00000   12.00000
# 75%     13.000000   13.000000   14.000000   13.00000   14.00000
# max     15.000000   15.000000   15.000000   15.00000   15.00000

# %%
df.國文.corr(df.數學)
# Out:
# -0.3108989822179331

# %%
df["總級分"] = df[["國文", "英文", "數學", "社會", "自然"]].sum(1)

# %%
df["主科"]= df.數學*1.5 + df.英文

# %%
df.head()
# Out:
#     姓名  國文  英文  數學  自然  社會  總級分    主科
# 0  劉俊安   9  10  15  10  13   57  32.5
# 1  胡玉華  10  10  10   8   9   47  25.0
# 2  黃淑婷  13  15   8  11  14   61  27.0
# 3  陳上紫  10  10   8   9  14   51  22.0
# 4  崔靜成  13  12  14  12  13   64  33.0

# %%
df.sort_values(by="總級分", ascending = False).head(20)
# Out:
#      姓名  國文  英文  數學  自然  社會  總級分    主科
# 80  施雅鈴  13  15  12  13  13   66  33.0
# 12  李正偉  11  15  11  14  15   66  31.5
# 54  陳怡潔  15  15   9  15  11   65  28.5
# 25  蔡亦瑄  13  13  14  13  12   65  34.0
# 57  胡淳茜  12  15  14  13  11   65  36.0
# 37  曾怡君  11  12  15  13  14   65  34.5
# 48  陳怡婷  15  14  12   9  15   65  32.0
# 64  俞志峰   9  14  13  14  15   65  33.5
# 83  李士賢  10  14  15  13  13   65  36.5
# 87  趙偉希  10  13  14  13  15   65  34.0
# 4   崔靜成  13  12  14  12  13   64  33.0
# 36  詹威德  12  13  15  10  14   64  35.5
# 11  周皇樺  13   9  13  14  15   64  28.5
# 68  劉麗芬   8  14  14  14  14   64  35.0
# 67  林哲法  14   9  15  10  14   62  31.5
# 20  陳智超  13   9  13  14  13   62  28.5
# 24  陳竹伯  10  12  15  10  14   61  34.5
# 65  謝雅琳  13  14  13  12   9   61  33.5
# 76  周育霖   9  12  15  13  12   61  34.5
# 44  童心怡  13  13  14   8  13   61  34.0

# %%
df.sort_values(["主科","總級分"], ascending = False).head(20)
# Out:
#      姓名  國文  英文  數學  自然  社會  總級分    主科
# 73  吳志遠  13  15  15   8   8   59  37.5
# 83  李士賢  10  14  15  13  13   65  36.5
# 57  胡淳茜  12  15  14  13  11   65  36.0
# 36  詹威德  12  13  15  10  14   64  35.5
# 70  葉儀依   9  13  15   8  14   59  35.5
# 68  劉麗芬   8  14  14  14  14   64  35.0
# 66  邱盈俊  10  14  14  13   8   59  35.0
# 37  曾怡君  11  12  15  13  14   65  34.5
# 24  陳竹伯  10  12  15  10  14   61  34.5
# 76  周育霖   9  12  15  13  12   61  34.5
# 25  蔡亦瑄  13  13  14  13  12   65  34.0
# 87  趙偉希  10  13  14  13  15   65  34.0
# 44  童心怡  13  13  14   8  13   61  34.0
# 27  馮白屏   8  13  14   8  10   53  34.0
# 64  俞志峰   9  14  13  14  15   65  33.5
# 65  謝雅琳  13  14  13  12   9   61  33.5
# 90  胡勝傑   8  11  15  10  15   59  33.5
# 85  張雅彬  10  11  15  12   8   56  33.5
# 80  施雅鈴  13  15  12  13  13   66  33.0
# 4   崔靜成  13  12  14  12  13   64  33.0

# %%
mydata = np.random.randn(4,3) #randn = 平均值是0, 標準差是1

# %%
mydata
# Out:
# array([[ 0.12028663, -1.1839551 ,  1.28828052],
#        [ 0.22327837,  0.09954361, -0.06921519],
#        [-0.11989186,  0.07833108, -0.17775719],
#        [ 0.591895  ,  0.68874501,  1.03748778]])

# %%
list("ABCDE")
# Out:
# ['A', 'B', 'C', 'D', 'E']

# %%
list("甲乙丙丁")
# Out:
# ['甲', '乙', '丙', '丁']

# %%
df1 = pd.DataFrame(mydata, columns= list("ABC"))

# %%
df1
# Out:
#           A         B         C
# 0  0.120287 -1.183955  1.288281
# 1  0.223278  0.099544 -0.069215
# 2 -0.119892  0.078331 -0.177757
# 3  0.591895  0.688745  1.037488

# %%
df2 = pd.DataFrame(np.random.randn(3,3), columns = list("ABC"))

# %%
df2
# Out:
#           A         B         C
# 0 -0.123618 -1.690548  0.288060
# 1  0.808288 -1.474018 -0.361124
# 2  1.772468 -1.612257 -0.228901

# %%
df3 = pd.concat([df1, df2], axis=0)

# %%
df3
# Out:
#           A         B         C
# 0  0.120287 -1.183955  1.288281
# 1  0.223278  0.099544 -0.069215
# 2 -0.119892  0.078331 -0.177757
# 3  0.591895  0.688745  1.037488
# 0 -0.123618 -1.690548  0.288060
# 1  0.808288 -1.474018 -0.361124
# 2  1.772468 -1.612257 -0.228901

# %%
 df3.index = range(7)

# %%
df3
# Out:
#           A         B         C
# 0  0.120287 -1.183955  1.288281
# 1  0.223278  0.099544 -0.069215
# 2 -0.119892  0.078331 -0.177757
# 3  0.591895  0.688745  1.037488
# 4 -0.123618 -1.690548  0.288060
# 5  0.808288 -1.474018 -0.361124
# 6  1.772468 -1.612257 -0.228901

# %%
df4 = pd.concat([df1, df2], axis = 1)

# %%
df4
# Out:
#           A         B         C         A         B         C
# 0  0.120287 -1.183955  1.288281 -0.123618 -1.690548  0.288060
# 1  0.223278  0.099544 -0.069215  0.808288 -1.474018 -0.361124
# 2 -0.119892  0.078331 -0.177757  1.772468 -1.612257 -0.228901
# 3  0.591895  0.688745  1.037488       NaN       NaN       NaN

# %%
df_hi = pd.read_csv("https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/ufo.csv")

# %%
df_hi
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# 5               Valley City             NaN           DISK    ND
# 6               Crater Lake             NaN         CIRCLE    CA
# 7                      Alma             NaN           DISK    MI
# 8                   Eklutna             NaN          CIGAR    AK
# 9                   Hubbard             NaN       CYLINDER    OR
# 10                  Fontana             NaN          LIGHT    CA
# 11                 Waterloo             NaN       FIREBALL    AL
# 12                   Belton             RED         SPHERE    SC
# ...

# %% [markdown]
# ### Groupby使用教學

# %%
df_state = df_hi.groupby("State").count()

# %%
df_state
# Out:
#        City  Colors Reported  Shape Reported  Time
# State
# AK      116               25              99   116
# AL      193               21             173   193
# AR      206               26             186   206
# AZ      736              145             644   738
# CA     2525              457            2148  2529
# CO      367               60             322   367
# CT      225               25             188   225
# Ca        1                0               1     1
# DE       43                5              38    43
# FL      835              120             727   837
# Fl        4                1               0     4
# GA      325               44             294   325
# HI       85               16              74    85
# IA      162               28             142   162
# ID      130               12             109   130
# IL      612              112             540   613
# IN      326               49             296   326
# ...

# %%
df_state.sort_values(by="Time", ascending = False, inplace=True )

# %%
df_state.head(10)
# Out:
#        City  Colors Reported  Shape Reported  Time
# State
# CA     2525              457            2148  2529
# WA     1320              269             925  1322
# TX     1025              138             923  1027
# NY      913              123             823   914
# FL      835              120             727   837
# AZ      736              145             644   738
# OH      665               93             605   667
# IL      612              112             540   613
# PA      598               97             519   598
# MI      590               78             504   591

# %%
df_state[:10].Time.plot(kind="bar") #畫長條圖的方式

# %% [markdown]
# ### "Groupby" application on drinks

# %%
drinks = pd.read_csv("http://bit.ly/drinksbycountry")

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.beer_servings.mean()
# Out:
# 106.16062176165804

# %%
# For each "continent" what is the mean of beer servings 
drinks.groupby("continent").beer_servings.mean()
# Out:
# continent
# Africa            61.471698
# Asia              37.045455
# Europe           193.777778
# North America    145.434783
# Oceania           89.687500
# South America    175.083333
# Name: beer_servings, dtype: float64

# %%
drinks.groupby("continent").beer_servings.agg(["count", "max", "min","mean"])
# Out:
#                count  max  min        mean
# continent
# Africa            53  376    0   61.471698
# Asia              44  247    0   37.045455
# Europe            45  361    0  193.777778
# North America     23  285    1  145.434783
# Oceania           16  306    0   89.687500
# South America     12  333   93  175.083333

# %%
#get the mean of different columns by the category of continent
drinks.groupby("continent").mean()
# Out:
#                beer_servings  spirit_servings  wine_servings  \
# continent
# Africa             61.471698        16.339623      16.264151
# Asia               37.045455        60.840909       9.068182
# Europe            193.777778       132.555556     142.222222
# North America     145.434783       165.739130      24.521739
# Oceania            89.687500        58.437500      35.625000
# South America     175.083333       114.750000      62.416667
#
#                total_litres_of_pure_alcohol
# continent
# Africa                             3.007547
# Asia                               2.170455
# Europe                             8.617778
# North America                      5.995652
# Oceania                            3.381250
# South America                      6.308333

# %%
drinks.groupby("continent").mean().plot(kind="bar")

# %% [markdown]
# ## Loc使用教學
#
# 1. 尋找特定資料
# 2. 更改特定資料

# %%
df = pd.DataFrame(np.random.randn(5,3), 
                  index=list(range(1,6)),
                 columns=list("ABC"))

# %%
df
# Out:
#           A         B         C
# 1 -2.098599 -1.700254 -1.287007
# 2  1.279271  1.102115 -0.383409
# 3  1.243370 -1.724149 -0.761090
# 4  0.478606  0.569472 -0.484593
# 5  0.890187 -0.209347 -0.687356

# %%
df[df.B>0]
# Out:
#           A         B         C
# 2  1.279271  1.102115 -0.383409
# 4  0.478606  0.569472 -0.484593

# %%
df[df.B>0]["C"] = 0
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df.loc[2:3, "B":"C"]
# Out:
#           B         C
# 2  1.102115 -0.383409
# 3 -1.724149 -0.761090

# %%
df.loc[2,"B"] = 1

# %%
df
# Out:
#           A         B         C
# 1 -2.098599 -1.700254 -1.287007
# 2  1.279271  1.000000 -0.383409
# 3  1.243370 -1.724149 -0.761090
# 4  0.478606  0.569472 -0.484593
# 5  0.890187 -0.209347 -0.687356

# %%
df.loc[df.B>0, "C"] = 0

# %%
df
# Out:
#           A         B         C
# 1 -2.098599 -1.700254 -1.287007
# 2  1.279271  1.000000  0.000000
# 3  1.243370 -1.724149 -0.761090
# 4  0.478606  0.569472  0.000000
# 5  0.890187 -0.209347 -0.687356

# %% [markdown]
# ## 玩玩真正的股票資料

# %%
import pandas_datareader.data as web

# %%
# yahoo資料源
df = web.DataReader("AAPL", "yahoo", start = "2012-9-1" , end = "2017-8-31")

# %%
df.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2012-08-31  95.514282  93.892860  95.321426  95.034286  84580300.0  83.044464
# 2012-09-04  96.448570  94.928574  95.108574  96.424286  91973000.0  84.259094
# 2012-09-05  96.621429  95.657143  96.510002  95.747147  84093800.0  83.667366
# 2012-09-06  96.898575  95.828575  96.167145  96.610001  97799100.0  84.421394
# 2012-09-07  97.497147  96.538574  96.864288  97.205711  82416600.0  84.941940

# %%
P = df["Adj Close"] #調整收盤價

# %%
P.plot()

# %%
# diff 為和前一個資料的差別
P.diff()
# Out:
# Date
# 2012-08-31         NaN
# 2012-09-04    1.214630
# 2012-09-05   -0.591728
# 2012-09-06    0.754028
# 2012-09-07    0.520546
# 2012-09-10   -2.209579
# 2012-09-11   -0.268394
# 2012-09-12    1.148491
# 2012-09-13    1.646545
# 2012-09-14    1.036125
# 2012-09-17    1.061081
# 2012-09-18    0.265900
# 2012-09-19    0.023705
# 2012-09-20   -0.424416
# 2012-09-21    0.173523
# 2012-09-24   -1.160965
# 2012-09-25   -2.153374
# 2012-09-26   -1.043633
# 2012-09-27    2.014839
# 2012-09-28   -1.775154
# 2012-10-01   -0.962456
# 2012-10-02    0.239677
# 2012-10-03    1.265816
# 2012-10-04   -0.580498
# 2012-10-05   -1.773888
# 2012-10-08   -1.800102
# 2012-10-09   -0.289604
# 2012-10-10    0.631668
# 2012-10-11   -1.599121
# 2012-10-12    0.200974
#                 ...
# 2017-07-21   -0.067429
# 2017-07-24    1.753342
# 2017-07-25    0.626175
# 2017-07-26    0.693634
# 2017-07-27   -2.793777
# 2017-07-28   -1.021164
# 2017-07-31   -0.741806
# 2017-08-01    1.271652
# ...

# %%
# 投資報酬率
r = P.diff()/P

# %%
r.plot()

# %%
# 得到100天到現在的變化
r[-100:].plot()

# %% [markdown]
# ## 移動平均

# %%
P.plot()
P.rolling(window = 20).mean().plot()
P.rolling(window=60).mean().plot()

# %%
P.rolling(window=60).mean().plot()

# %% [markdown]
# ## 練習題

# %% [markdown]
# ### 閏年計算機:
# - 西元年份除以4不可整除，為平年。
# - 西元年份除以4可整除，且除以100不可整除，為閏年。
# - 西元年份除以100可整除，且除以400不可整除，為平年
# - 西元年份除以400可整除，為閏年。

# %%
def leap_year():
    num = input("Please type in a year ")
    if (int(num)%4 == 0 & int(num)%10 != 0) or (int(num)%4 == 0 & int(num)%400 == 0):
        print(f"{num} is a leap year")
    else:
        print(f"{num} is not a leap year")

# %%
leap_year()
# Out:
# Please type in a year 2019
# 2019 is not a leap year

# %% [markdown]
# ### 錄取分數表格

# %%
score = np.array([86.5, 79.4, 88.2, 96.5, 86.3, 76.8, 96.1, 78.5, 82.4, 88.6])

# %%
score_chart = pd.DataFrame([
[2, 2, 0, 1, 0, 0, 0, 1, 1, 0],
[1, 1.5, 0, 1.5, 0, 0, 0, 0, 0, 0],
[1, 1.5, 0, 2, 0, 0, 0, 0, 0, 0],
[1.5, 2, 0, 2, 0, 0, 0, 0, 0, 0],
[1.5, 2, 0, 2, 0, 0, 0, 1, 1, 0],
[1, 2, 0, 1, 0, 0, 0, 1, 0, 1],
[1, 1.5, 0, 1.25, 0, 0, 0, 0, 0, 1.25],
[1, 1, 1.5, 0, 1, 1, 0, 0, 0, 0],
[1.5, 2, 0, 1.25, 0, 0, 0, 1, 1, 0]], 
index = ["土語系","財政系","金融系","國貿系","會計系","法律系","公行系","應數系","教育系"], 
columns = ["國文","英文","數甲","數乙","物理","化學","生物","歷史","地理","公民"])

# %%
score_chart
# Out:
#       國文   英文   數甲    數乙  物理  化學  生物  歷史  地理    公民
# 土語系  2.0  2.0  0.0  1.00   0   0   0   1   1  0.00
# 財政系  1.0  1.5  0.0  1.50   0   0   0   0   0  0.00
# 金融系  1.0  1.5  0.0  2.00   0   0   0   0   0  0.00
# 國貿系  1.5  2.0  0.0  2.00   0   0   0   0   0  0.00
# 會計系  1.5  2.0  0.0  2.00   0   0   0   1   1  0.00
# 法律系  1.0  2.0  0.0  1.00   0   0   0   1   0  1.00
# 公行系  1.0  1.5  0.0  1.25   0   0   0   0   0  1.25
# 應數系  1.0  1.0  1.5  0.00   1   1   0   0   0  0.00
# 教育系  1.5  2.0  0.0  1.25   0   0   0   1   1  0.00

# %%
weigh = np.array([[2, 2, 0, 1, 0, 0, 0, 1, 1, 0],
[1, 1.5, 0, 1.5, 0, 0, 0, 0, 0, 0],
[1, 1.5, 0, 2, 0, 0, 0, 0, 0, 0],
[1.5, 2, 0, 2, 0, 0, 0, 0, 0, 0],
[1.5, 2, 0, 2, 0, 0, 0, 1, 1, 0],
[1, 2, 0, 1, 0, 0, 0, 1, 0, 1],
[1, 1.5, 0, 1.25, 0, 0, 0, 0, 0, 1.25],
[1, 1, 1.5, 0, 1, 1, 0, 0, 0, 0],
[1.5, 2, 0, 1.25, 0, 0, 0, 1, 1, 0]])

# %%
weigh_score = np.dot(weigh, score)

# %%
score_chart["加權成績"] = weigh_score

# %%
score_chart
# Out:
#       國文   英文   數甲    數乙  物理  化學  生物  歷史  地理    公民     加權成績
# 土語系  2.0  2.0  0.0  1.00   0   0   0   1   1  0.00  589.200
# 財政系  1.0  1.5  0.0  1.50   0   0   0   0   0  0.00  350.350
# 金融系  1.0  1.5  0.0  2.00   0   0   0   0   0  0.00  398.600
# 國貿系  1.5  2.0  0.0  2.00   0   0   0   0   0  0.00  481.550
# 會計系  1.5  2.0  0.0  2.00   0   0   0   1   1  0.00  642.450
# 法律系  1.0  2.0  0.0  1.00   0   0   0   1   0  1.00  508.900
# 公行系  1.0  1.5  0.0  1.25   0   0   0   0   0  1.25  436.975
# 應數系  1.0  1.0  1.5  0.00   1   1   0   0   0  0.00  461.300
# 教育系  1.5  2.0  0.0  1.25   0   0   0   1   1  0.00  570.075
